# %%
from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
# from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
# from selenium.webdriver.firefox.options import Options
from selenium.webdriver.support.ui import WebDriverWait

# NoSuchElementException
from selenium.common.exceptions import (
    NoSuchElementException,
    # InvalidSelectorException,
    # ElementNotInteractableException,
    # ElementClickInterceptedException,
    # TimeoutException,
    # StaleElementReferenceException,
    # InvalidArgumentException,
)

import time
import datetime

print("Godkjent importert")
# Out:
# Godkjent importert

# %%
from helloworld import elements_complete
if elements_complete is not None:
    print('elements_complete Exists')
else:
    print('elements_complete Does Not Exist')
# Out:
# elements_complete Exists

# %%
# Create Water from Hydrogen and Oxygen
def CreateWater(Element_Name): #Symbol, Atomic_Number):
    if elements_complete is not None:
        for element in elements_complete:
            if element['name'] == Element_Name:
                return element
            else:
                print(f"Element Not Found Write Element Name, not {Element_Name}")
                # did you mean ?
                print(print(f" {Element_Name}"))
                
    else:
        print('elements_complete Does Not Exist')
        return None

# %%
# Call CreateWater Function
# from selenium.webdriver.common.by import By

# selecting_element = CreateWater('Hydrogen')

# driver = webdriver.Chrome()
# driver.get("https://pubchem.ncbi.nlm.nih.gov/periodic-table/#view=table")
# # driver.get("https://pubchem.ncbi.nlm.nih.gov/element/3")
# driver.maximize_window()

# # Fill out the form with data
# title = driver.title

# text_box_id = driver.find_element(by=By.ID, value='an-1')


# driver.maximize_window()
def test_eight_components():
    
    driver = webdriver.Chrome()
    driver.get("https://pubchem.ncbi.nlm.nih.gov/periodic-table/#view=table")
    
    for i in range(1, 100):
        div = driver.find_element(by=By.ID, value=f"an-{i}") # #an-1
        # find ALL div in that have  attribute "data-tooltip" that have ="Symbol"
        Symbol_div = div.find_element(by=By.XPATH, value=".//div[@data-tooltip='Symbol']")
        print(Symbol_div.text)
print("quit")

test_eight_components()
# Out:
# quit
# H
# He
# Li
# Be
# B
# C
# N
# O
# F
# Ne
# Na
# Mg
# Al
# Si
# P
# S
# Cl
# Ar
# K
# Ca
# Sc
# Ti
# V
# Cr
# Mn
# Fe
# Co
# Ni
# Cu
# Zn
# Ga
# Ge
# As
# Se
# Br
# Kr
# Rb
# Sr
# Y
# Zr
# Nb
# Mo
# Tc
# Ru
# Rh
# Pd
# Ag
# Cd
# In
# Sn
# Sb
# Te
# I
# Xe
# Cs
# Ba
# La
# Ce
# Pr
# Nd
# Pm
# Sm
# Eu
# Gd
# Tb
# Dy
# Ho
# Er
# Tm
# Yb
# Lu
# Hf
# Ta
# W
# Re
# Os
# Ir
# Pt
# Au
# Hg
# Tl
# Pb
# Bi
# Po
# At
# Rn
# Fr
# Ra
# Ac
# Th
# Pa
# U
# Np
# Pu
# Am
# Cm
# Bk
# Cf
# Es
